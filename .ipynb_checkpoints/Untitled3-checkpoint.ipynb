# %%
from dlisio import dlis

# %%
with dlis.load('Data/14_26a-_10_dwl_DWL_WIRE_243109789.dlis') as (f, *tail):
    pass

frame1 = f.object('FRAME','0_500000B1')
frame2 = f.object('FRAME','0_250000B0')
print(frame1)
print(frame2)
# Out:
# Frame(0_500000B1)
# Frame(0_250000B0)

# %%
f1curves = frame1.curves()
